# %% [markdown]
# # 0. 개요

# %% [markdown]
# # 1. TensorFlow 및 Keras

# %%
import keras
keras.__version__
# Out:
# '2.4.3'

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
np.__version__
# Out:
# '1.18.5'

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
keras.__version__
# Out:
# '2.4.0'

# %% [markdown]
# # 2. 파일 업로드

# %% [markdown]
# ## 2.1 일반 업로드

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bbfeccfc-8841-4a00-aeae-08d9268742c5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bbfeccfc-8841-4a00-aeae-08d9268742c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lenna.png to lenna.png

# %%
import cv2

img = cv2.imread("lenna.png")
img.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ## 2.2 구글 드라이브 연동

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import cv2
import numpy as np

img: np.ndarray = cv2.imread("/gdrive/My Drive/lecture/202011_2_lecture/lenna.png")
img.shape
# Out:
# (512, 512, 3)
