# %% [markdown]
# # LSTM 방법론을 활용한 시계열 데이터 예측

# %% [markdown]
# ### library 불러오기

# %%
# tensorflow와 keras가 설치되어 있지 않은 경우 아래 ! pip 코드를 실행
# ! pip install tensorflow
# ! pip install keras


# 라이브러리 블러오기

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import preprocessing, metrics
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential, load_model
from keras.layers import Input, LSTM, Dropout, Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import np_utils

from datetime import datetime, timedelta, timezone

# %% [markdown]
# ### 데이터 불러오기

# %%
# 데이터 불러오기
df = pd.read_csv('time_series_samp.csv', header = None)

# 컬럼명 정의
df.columns = ['date','value']

# 인덱스 정의
df.index = df["date"].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))

# 불필요한 컬럼 제거
df = df.drop(['date'], axis=1)


# 시각화 옵션
plt.rcParams["figure.figsize"] = (16,7)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['axes.grid'] = True

# 시각화하기
plt.plot(df['value'], label = 'timeseries data')
plt.legend()
plt.show()

# %% [markdown]
# ### 분석 목표
#  - 2020년 9월 1일부터 12월 20일까지 시계열 데이터를 활용하여 LSTM 예측 모델을 구축한 후 12월 26일부터 31일까지 5일을 예측해 보기

# %% [markdown]
# ### 데이터 전처리

# %%
# train data와 test 데이터로 나누기
train = df[:'2020-12-24']

# 스케일링 하기(-1 ~ 1 으로 스케일링)
scaler = preprocessing.MinMaxScaler(feature_range=(-1,1))

# 스케일링 기준 정의
scaler.fit(df)

# 훈련 데이터 스케일링
scaled_train = scaler.transform(train)

# 시계열 예측을 위한 타임 스텝 정의
time_step= 10

# 타임 스텝에 따라서 훈련 데이터 나누기
n_rows = len(scaled_train)

features_set_train = []
labels_set_train = []

for i in range(time_step, n_rows):
    features_set_train.append(scaled_train[i-time_step:i])
    labels_set_train.append(scaled_train[i])

features_train, features_val, labels_train, labels_val = train_test_split(features_set_train, labels_set_train, test_size=0.2, shuffle=False)

print('feature_train의 타입 :', type(features_train))
print('labels_train의 타입 :', type(labels_train))
# Out:
# feature_train의 타입 : <class 'list'>
# labels_train의 타입 : <class 'list'>

# %%
# LSTM 모델에 활용하기 위하여 array 형태로 변경(np.array)
features_train, labels_train = np.array(features_train), np.array(labels_train)
features_val, labels_val = np.array(features_val), np.array(labels_val)


# array의 차원을 변경(np.reshape)
features_train = np.reshape(features_train, (features_train.shape[0], features_train.shape[1], 1))
features_val = np.reshape(features_val, (features_val.shape[0], features_val.shape[1], 1))


print('features_train의 타입 :', type(features_train))
print('features_train의 차원 :', features_train.shape)
# Out:
# features_train의 타입 : <class 'numpy.ndarray'>
# features_train의 차원 : (84, 10, 1)

# %% [markdown]
# ### 분석에서 활용할 모듈 정의

# %%
# 손실(loss) 이력 클래스 정의 - 모델 학습 과정을 살펴보기 위해서
class LossHistory(keras.callbacks.Callback):
    def init(self):
        self.losses = []
        self.val_losses = []
        
    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        self.val_losses.append(logs.get('val_loss'))

        
# Early stopping
early_stop_callback = EarlyStopping(monitor = 'val_loss', mode = 'min', patience = 30)

# Model checkpoint (최적의 모델을 저장하는 모듈)
model_checkpoint = ModelCheckpoint(filepath = 'LSTM_model.h5', monitor = 'val_loss', save_best_only = True, verbose = 1)

# %% [markdown]
# ### LSTM 모델 구성하기

# %%
# LSTM model - 단층 모형

# sequential 모델 선언
model = Sequential()

## LSTM layer
model.add(LSTM(units = 70, batch_input_shape = (1, features_train.shape[1], 1), activation = 'tanh'))

## Dense Layer (활성화 함수 = tanh)
model.add(Dense(units = 1, activation = 'tanh'))

# model name
model._name = 'model'

## compile
model.compile(optimizer = 'adam', loss = 'mse', metrics = ["mse","mae",'mape'])

# %% [markdown]
# ### 모델 학습하기

# %%
# 손실 이력 객체 생성
history = LossHistory()
history.init()


# epoch(훈련 반복 횟수) 정의
num_epochs = 100

# 모형 fitting 하기 
model.fit(features_train, labels_train, validation_data = (features_val, labels_val), epochs=num_epochs, batch_size=1, verbose=1, shuffle=False, callbacks=[history,model_checkpoint])
# Out:
# Epoch 1/100
# 75/84 [=========================>....] - ETA: 0s - loss: 0.0476 - mse: 0.0476 - mae: 0.1704 - mape: 76.6334
# Epoch 00001: val_loss improved from inf to 0.08184, saving model to LSTM_model.h5
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0448 - mse: 0.0448 - mae: 0.1663 - mape: 88.2334 - val_loss: 0.0818 - val_mse: 0.0818 - val_mae: 0.2568 - val_mape: 87.4402
# Epoch 2/100
# 82/84 [============================>.] - ETA: 0s - loss: 0.0332 - mse: 0.0332 - mae: 0.1436 - mape: 83.2240
# Epoch 00002: val_loss improved from 0.08184 to 0.07205, saving model to LSTM_model.h5
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0331 - mse: 0.0331 - mae: 0.1438 - mape: 83.7840 - val_loss: 0.0720 - val_mse: 0.0720 - val_mae: 0.2400 - val_mape: 82.3937
# Epoch 3/100
# 65/84 [======================>.......] - ETA: 0s - loss: 0.0337 - mse: 0.0337 - mae: 0.1457 - mape: 71.0874
# Epoch 00003: val_loss improved from 0.07205 to 0.05861, saving model to LSTM_model.h5
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0322 - mse: 0.0322 - mae: 0.1414 - mape: 82.3123 - val_loss: 0.0586 - val_mse: 0.0586 - val_mae: 0.2147 - val_mape: 74.6724
# Epoch 4/100
# 79/84 [===========================>..] - ETA: 0s - loss: 0.0315 - mse: 0.0315 - mae: 0.1387 - mape: 73.8605
# Epoch 00004: val_loss improved from 0.05861 to 0.05227, saving model to LSTM_model.h5
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0312 - mse: 0.0312 - mae: 0.1393 - mape: 82.0439 - val_loss: 0.0523 - val_mse: 0.0523 - val_mae: 0.2012 - val_mape: 70.5867
# Epoch 5/100
# 65/84 [======================>.......] - ETA: 0s - loss: 0.0321 - mse: 0.0321 - mae: 0.1423 - mape: 71.2628
# Epoch 00005: val_loss improved from 0.05227 to 0.04620, saving model to LSTM_model.h5
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0308 - mse: 0.0308 - mae: 0.1388 - mape: 81.6918 - val_loss: 0.0462 - val_mse: 0.0462 - val_mae: 0.1872 - val_mape: 66.3147
# Epoch 6/100
# 66/84 [======================>.......] - ETA: 0s - loss: 0.0312 - mse: 0.0312 - mae: 0.1396 - mape: 70.3230
# Epoch 00006: val_loss improved from 0.04620 to 0.04064, saving model to LSTM_model.h5
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0305 - mse: 0.0305 - mae: 0.1383 - mape: 81.2384 - val_loss: 0.0406 - val_mse: 0.0406 - val_mae: 0.1732 - val_mape: 61.9861
# Epoch 7/100
# 84/84 [==============================] - ETA: 0s - loss: 0.0301 - mse: 0.0301 - mae: 0.1376 - mape: 81.2671
# Epoch 00007: val_loss improved from 0.04064 to 0.03817, saving model to LSTM_model.h5
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0301 - mse: 0.0301 - mae: 0.1376 - mape: 81.2671 - val_loss: 0.0382 - val_mse: 0.0382 - val_mae: 0.1662 - val_mape: 59.8373
# Epoch 8/100
# 84/84 [==============================] - ETA: 0s - loss: 0.0301 - mse: 0.0301 - mae: 0.1379 - mape: 80.8289
# Epoch 00008: val_loss improved from 0.03817 to 0.03305, saving model to LSTM_model.h5
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0301 - mse: 0.0301 - mae: 0.1379 - mape: 80.8289 - val_loss: 0.0331 - val_mse: 0.0331 - val_mae: 0.1511 - val_mape: 55.2117
# Epoch 9/100
# 77/84 [==========================>...] - ETA: 0s - loss: 0.0307 - mse: 0.0307 - mae: 0.1378 - mape: 74.7962
# Epoch 00009: val_loss improved from 0.03305 to 0.03165, saving model to LSTM_model.h5
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0297 - mse: 0.0297 - mae: 0.1369 - mape: 80.7927 - val_loss: 0.0316 - val_mse: 0.0316 - val_mae: 0.1462 - val_mape: 53.6553
# Epoch 10/100
# 69/84 [=======================>......] - ETA: 0s - loss: 0.0295 - mse: 0.0295 - mae: 0.1359 - mape: 69.5229
# Epoch 00010: val_loss improved from 0.03165 to 0.02830, saving model to LSTM_model.h5
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0298 - mse: 0.0298 - mae: 0.1372 - mape: 80.8800 - val_loss: 0.0283 - val_mse: 0.0283 - val_mae: 0.1342 - val_mape: 49.9968
# Epoch 11/100
# 83/84 [============================>.] - ETA: 0s - loss: 0.0299 - mse: 0.0299 - mae: 0.1370 - mape: 80.3200
# Epoch 00011: val_loss improved from 0.02830 to 0.02435, saving model to LSTM_model.h5
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0298 - mse: 0.0298 - mae: 0.1371 - mape: 80.5469 - val_loss: 0.0243 - val_mse: 0.0243 - val_mae: 0.1197 - val_mape: 45.5871
# Epoch 12/100
# 82/84 [============================>.] - ETA: 0s - loss: 0.0297 - mse: 0.0297 - mae: 0.1358 - mape: 80.0922
# Epoch 00012: val_loss improved from 0.02435 to 0.02366, saving model to LSTM_model.h5
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0296 - mse: 0.0296 - mae: 0.1363 - mape: 80.8017 - val_loss: 0.0237 - val_mse: 0.0237 - val_mae: 0.1163 - val_mape: 44.5263
# Epoch 13/100
# 80/84 [===========================>..] - ETA: 0s - loss: 0.0300 - mse: 0.0300 - mae: 0.1361 - mape: 76.6015
# Epoch 00013: val_loss improved from 0.02366 to 0.02031, saving model to LSTM_model.h5
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0298 - mse: 0.0298 - mae: 0.1368 - mape: 80.1462 - val_loss: 0.0203 - val_mse: 0.0203 - val_mae: 0.1058 - val_mape: 41.3315
# Epoch 14/100
# 83/84 [============================>.] - ETA: 0s - loss: 0.0294 - mse: 0.0294 - mae: 0.1354 - mape: 80.0877
# Epoch 00014: val_loss improved from 0.02031 to 0.02021, saving model to LSTM_model.h5
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0293 - mse: 0.0293 - mae: 0.1356 - mape: 80.3724 - val_loss: 0.0202 - val_mse: 0.0202 - val_mae: 0.1057 - val_mape: 41.1059
# Epoch 15/100
# 84/84 [==============================] - ETA: 0s - loss: 0.0295 - mse: 0.0295 - mae: 0.1361 - mape: 79.8992
# Epoch 00015: val_loss improved from 0.02021 to 0.01830, saving model to LSTM_model.h5
# 84/84 [==============================] - 0s 3ms/step - loss: 0.
val_loss did not improve from 0.01692
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0262 - mse: 0.0262 - mae: 0.1273 - mape: 75.0672 - val_loss: 0.1027 - val_mse: 0.1027 - val_mae: 0.2800 - val_mape: 86.9116
# Epoch 63/100
# 75/84 [=========================>....] - ETA: 0s - loss: 0.0271 - mse: 0.0271 - mae: 0.1274 - mape: 69.7660
# Epoch 00063: val_loss did not improve from 0.01692
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0262 - mse: 0.0262 - mae: 0.1271 - mape: 74.9407 - val_loss: 0.1053 - val_mse: 0.1053 - val_mae: 0.2834 - val_mape: 87.8266
# Epoch 64/100
# 83/84 [============================>.] - ETA: 0s - loss: 0.0264 - mse: 0.0264 - mae: 0.1273 - mape: 74.9671
# Epoch 00064: val_loss did not improve from 0.01692
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0262 - mse: 0.0262 - mae: 0.1270 - mape: 74.9357 - val_loss: 0.1065 - val_mse: 0.1065 - val_mae: 0.2851 - val_mape: 88.3528
# Epoch 65/100
# 82/84 [============================>.] - ETA: 0s - loss: 0.0262 - mse: 0.0262 - mae: 0.1265 - mape: 74.1669
# Epoch 00065: val_loss did not improve from 0.01692
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0261 - mse: 0.0261 - mae: 0.1269 - mape: 74.8028 - val_loss: 0.1087 - val_mse: 0.1087 - val_mae: 0.2878 - val_mape: 89.1037
# Epoch 66/100
# 73/84 [=========================>....] - ETA: 0s - loss: 0.0275 - mse: 0.0275 - mae: 0.1282 - mape: 70.0280
# Epoch 00066: val_loss did not improve from 0.01692
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0261 - mse: 0.0261 - mae: 0.1268 - mape: 74.8086 - val_loss: 0.1100 - val_mse: 0.1100 - val_mae: 0.2897 - val_mape: 89.6889
# Epoch 67/100
# 76/84 [==========================>...] - ETA: 0s - loss: 0.0269 - mse: 0.0269 - mae: 0.1275 - mape: 69.4547
# Epoch 00067: val_loss did not improve from 0.01692
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0261 - mse: 0.0261 - mae: 0.1267 - mape: 74.6820 - val_loss: 0.1111 - val_mse: 0.1111 - val_mae: 0.2910 - val_mape: 90.0471
# Epoch 68/100
# 78/84 [==========================>...] - ETA: 0s - loss: 0.0268 - mse: 0.0268 - mae: 0.1278 - mape: 72.3669
# Epoch 00068: val_loss did not improve from 0.01692
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0260 - mse: 0.0260 - mae: 0.1266 - mape: 74.6988 - val_loss: 0.1125 - val_mse: 0.1125 - val_mae: 0.2929 - val_mape: 90.6380
# Epoch 69/100
# 74/84 [=========================>....] - ETA: 0s - loss: 0.0272 - mse: 0.0272 - mae: 0.1276 - mape: 69.6654
# Epoch 00069: val_loss did not improve from 0.01692
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0260 - mse: 0.0260 - mae: 0.1266 - mape: 74.5820 - val_loss: 0.1130 - val_mse: 0.1130 - val_mae: 0.2935 - val_mape: 90.7890
# Epoch 70/100
# 70/84 [========================>.....] - ETA: 0s - loss: 0.0278 - mse: 0.0278 - mae: 0.1291 - mape: 68.1578
# Epoch 00070: val_loss did not improve from 0.01692
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0260 - mse: 0.0260 - mae: 0.1265 - mape: 74.5974 - val_loss: 0.1144 - val_mse: 0.1144 - val_mae: 0.2954 - val_mape: 91.3813
# Epoch 71/100
# 77/84 [==========================>...] - ETA: 0s - loss: 0.0267 - mse: 0.0267 - mae: 0.1271 - mape: 71.9877
# Epoch 00071: val_loss did not improve from 0.01692
# 84/84 [==============================] - 0s 3ms/step - loss: 0.
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0255 - mse: 0.0255 - mae: 0.1249 - mape: 73.6464 - val_loss: 0.1347 - val_mse: 0.1347 - val_mae: 0.3209 - val_mape: 99.2140

# %% [markdown]
# ### 저장된 최적의 모델을 불러오고 학습과정 살펴보기

# %%
# 저장된 최적으 모형을 불러와서 model 에 저장하여 활용
model = load_model('LSTM_model.h5')
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (1, 70)                   20160
# _________________________________________________________________
# dense (Dense)                (1, 1)                    71
# =================================================================
# Total params: 20,231
# Trainable params: 20,231
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 6. 학습과정 살펴보기

plt.plot(history.losses)
plt.plot(history.val_losses)

plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss','validation loss'], loc='upper center')
plt.show()

# %% [markdown]
# ### 모델 평가해 보기

# %%
# 7. 모델 평가하기
scores = model.evaluate(features_train, labels_train, batch_size=1) # 훈련데이터로 평가
scores = model.evaluate(features_val, labels_val, batch_size=1)     # 밸리데이션 데이터로 평가
# Out:
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0342 - mean_squared_error: 0.0342 - mean_absolute_error: 0.1512 - mean_absolute_percentage_error: 71.3468
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - mean_absolute_error: 0.1038 - mean_absolute_percentage_error: 40.4267

# %% [markdown]
# ### 예측 수행하기

# %%
# 예측 수행하기

# 예측 모델에 들어갈 초기값 설정
seq_in = scaled_train[-time_step:]

# 예측구간 계산을 위해 평균값과 표준편차, 상한, 하한을 담을 그릇 선언
mean_pred_val = []

# 몇 개를 예측할지 정의
pred_count = (df.index[-1]-train.index[-1]).days      # 미래의 7일을 예측.

# 반복적인 예측을 수행하기 위해 for loop 구성 -> pred_count 만큼 반복
for i in range(pred_count):
    
    # 예측 모델에 들어가는 input 데이터 구성
    sample_in = np.array(seq_in)
    sample_in = np.reshape(seq_in, (seq_in.shape[1], seq_in.shape[0], 1)) # 샘플 수, 타입스텝 수, 속성 수

    
    # 실제 예측(prediction)
    pred_out = model.predict(sample_in)
 

    # 예측값을 다시 입력 데이터에 추가
    seq_in = np.append(seq_in, np.reshape(pred_out[0], (1,1)), axis = 0)
    seq_in = np.delete(seq_in, [0], axis = 0)
    
    
    # 실제값으로 표현하기 위해 inverse 스케일링
    pred = scaler.inverse_transform(pred_out)
    mean_pred_val.append(pred)
        
    # 반복 횟수를 출력
    print(i+1, '/', pred_count, 'days')
    

# 최종 예측값과 예측구간 상한과 하한을 데이터 프레임으로 만들기
pred_df = pd.DataFrame({'mean_predict_value':mean_pred_val},
                        index = pd.date_range(start = df.index[-pred_count], periods = pred_count, freq='D'))
# Out:
# 1 / 7 days
# 2 / 7 days
# 3 / 7 days
# 4 / 7 days
# 5 / 7 days
# 6 / 7 days
# 7 / 7 days

# %% [markdown]
# ### 예측 결과물 시각화 하기

# %%
# 최종 결과를 시각화
plt.plot(df['2020-12-01':], color = 'grey', alpha = 0.4, linestyle = 'dashed', lw = 2)
plt.plot(train['2020-12-01':])
plt.plot(pred_df['mean_predict_value'])

plt.grid(True, lw=0.1, linestyle = 'dashed')
plt.legend(['simulation data','train data','prediction','95% CI'])
