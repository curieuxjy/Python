# %% [markdown]
# [![Colab Badge](http://img.shields.io/badge/Colaboratory-black?style=for-the-badge&logo=google-colab)](https://colab.research.google.com/github/curieuxjy/Python/blob/master/Songorithm/leetcode/338_counting_bits.ipynb)

# %% [markdown]
# [counting-bits](https://leetcode.com/problems/counting-bits/)

# %% [markdown]
# my solution:

# %%
1//2
# Out:
# 0

# %%
from typing import List

class Solution:
    def countBits(self, num: int) -> List[int]:
        answer = []
     
        for target in range(num+1):
            count = 0
            bin_num = []
            work = target
            print()
            print(work//2)
            if (work//2)==1:
                pass
            elif (work//2)!=0:
                pass
            else:
                pass
            while (work//2)!=0:
                
                remain = work%2
                nom = work//2
                prin(remain, nom, "~~~~~")
                bin_num.insert(0,remain)
                if nom==1:
                    bin_num.insert(0, nom)
                work = nom
                print(work)
                
            count = sum(bin_num)
#             print(work, bin_num, count)
            answer.append(count)
        return answer

# %%
sol = Solution()
sol.countBits(1)
# Out:
# 0
#
# 0
# [0, 0]

# %%
# %%timeit
sol.countBits(5)
# Out:
# 0 [] 0
# 1 [] 0
# 1 [1, 0] 1
# 1 [1, 1] 2
# 1 [1, 0, 0] 1
# 1 [1, 0, 1] 2
# 0 [] 0
# 1 [] 0
# 1 [1, 0] 1
# 1 [1, 1] 2
# 1 [1, 0, 0] 1
# 1 [1, 0, 1] 2
# 0 [] 0
# 1 [] 0
# 1 [1, 0] 1
# 1 [1, 1] 2
# 1 [1, 0, 0] 1
# 1 [1, 0, 1] 2
# 0 [] 0
# 1 [] 0
# 1 [1, 0] 1
# 1 [1, 1] 2
# 1 [1, 0, 0] 1
# 1 [1, 0, 1] 2
# 0 [] 0
# 1 [] 0
# 1 [1, 0] 1
# 1 [1, 1] 2
# 1 [1, 0, 0] 1
# 1 [1, 0, 1] 2
# 0 [] 0
# 1 [] 0
# 1 [1, 0] 1
# 1 [1, 1] 2
# 1 [1, 0, 0] 1
# 1 [1, 0, 1] 2
# 0 [] 0
# 1 [] 0
# 1 [1, 0] 1
# 1 [1, 1] 2
# 1 [1, 0, 0] 1
# 1 [1, 0, 1] 2
# 0 [] 0
# 1 [] 0
# 1 [1, 0] 1
# 1 [1, 1] 2
# 1 [1, 0, 0] 1
# 1 [1, 0, 1] 2
# 0 [] 0
# 1 [] 0
# 1 [1, 0] 1
# 1 [1, 1] 2
# 1 [1, 0, 0] 1
# 1 [1, 0, 1] 2
# 0 [] 0
# 1 [] 0
# 1 [1, 0] 1
# 1 [1, 1] 2
# 1 [1, 0, 0] 1
# 1 [1, 0, 1] 2
# 0 [] 0
# 1 [] 0
# 1 [1, 0] 1
# 1 [1, 1] 2
# 1 [1, 0, 0] 1
# 1 [1, 0, 1] 2
# 0 [] 0
# 1 [] 0
# 1 [1, 0] 1
# 1 [1, 1] 2
# 1 [1, 0, 0] 1
# 1 [1, 0, 1] 2
# 0 [] 0
# 1 [] 0
# 1 [1, 0] 1
# 1 [1, 1] 2
# 1 [1, 0, 0] 1
# 1 [1, 0, 1] 2
# 0 [] 0
# ...

# %%
from typing import List

class Solution:
    def countBits(self, num: int) -> List[int]:
        if num==0:
            return [0]

        answer = []
        count = 0
        for target in range(1, num+1):
            bin_num = []
            work = target

            while (work//2)!=0:
                
                remain = work%2
                nom = work//2
                bin_num.insert(0,remain)
                work = nom
                
            bin_num.insert(0,1)
            count = sum(bin_num)
            print(work, bin_num, count)
            answer.append(count)
        return answer

# %%
sol = Solution()

# %%
# %%timeit
sol.countBits(5)
# Out:
# 1 [1] 1
# 1 [1, 0] 1
# 1 [1, 1] 2
# 1 [1, 0, 0] 1
# 1 [1, 0, 1] 2
# [1, 1, 2, 1, 2]
