# %% [markdown]
# # Controls
# ## `While`
# `while`은 loop를 만드는 대표적인 방법 중 하나이다. `boolean`을 배우고 `while`을 배우는 이유는 어떤 loop안에 들어갈 때는 조건문의 `True/False`를 판단하여 들어가기 때문이다.
# ```
# a = [1, 2, 3, 4]
# while a: # a가 참인 동안
#     a.pop() # 리스트의 마지막 요소를 하나씩 꺼낸다.
# ```
# output
# ```
# 4
# 3
# 2
# 1
# ```
# ```
# while 조건문:
#     수행할 문장
# ```
# 이는 파이썬 프로그래밍에서 매우 자주 이용하는 기법 중 하나이다.

# %% [markdown]
# ---
# ## `if/elif/else`
#
# `if`도 loop를 만드는 대표적인 방법이다. `elif`, `else`와 같이 쓰이기도 한다(필수는 아니다).
# ```
# if 조건문 :
#     수행할 문장
# else:
#     수행할 문장
# ```
# 이와 같은 형태로 쓰인다.
#
# 앞서 `bool()`함수를 이용하여 `True/False`를 return하였는데,
#
# 이를 `if/else`를 써서 표현해 볼 수도 있다.
# ```
# if []:                          #[]은  True 인가 False 인가
#     print("True")
# else:
#     print("False")
# ```
# output `False`
#
# 위의 코드는 `bool([])`과 동일하다.
#
# ```
# if [1, 2, 3]:                   #[1, 2, 3]은 True 인가 False 인가
#     print("True")
# else:
#     print("False")
# ```
# output `True`
#
# 위의 코드는 `bool([1, 2, 3])`과 동일하다.
#
#
# 조건문은 얼마든지 늘릴 수 있다.
# * 순서는 `if` → `elif` → `else`
# ```
# if 조건문(1) :
#     수행할 문장
# elif 조건문(2) :
#     수행할 문장
# else:
#     수행할 문장
# ```
# 하나의 예시를 보자. 신호등의 색을 알려주는 코드를 하나 만들어보자.
#     * 신호등의 색은 red, green, yellow 3가지 색만이 있다고 가정
#     * 색은 string 자료형으로, 변수 color로 저장
# ```
#     if color = "red':
#         print("The traffic light is RED!")
#     elif color = "green":
#         print("The traffic light is Green.")
#     else:
#         print("The traffic light is Yellow.")
# ```

# %%
# 연습해봅시다.

# %% [markdown]
# ## if 문의 기본구조
#
# if와 else를 이용한 조건문의 기본구조
#
# ```
# if 조건문:
#     수행할 문장1
#     수행할 문장2
#     ...
# else:
#     수행할 문장A
#     수행할 문장B
#     ...
# ```
#
# 조건문을 판단하여 참 → if문 바로 다음의 문장(if block)들을 수행하고,
#
# 조건문이 거짓 → else문 다음의 문장(else block)들을 수행한다.
#
# (else문은 if문 없이 독립적으로 사용할 수 없다.)

# %%
#if이 만약 ~라면 ~해!하는 문법구조라고 생각하시면 될 것 같아요. 아직 익숙하진 않지만 한번 연습해 봅시다!
#만약 전구의 신호가 1이라면 불이 켜진다는 간단한 if문을 만들어 볼까요?

signal = #채워주세요

if #채워주세요
    print("Light on!")
else:
    print("Light off")

# %% [markdown]
# # if 문
# > 돈이 있으면 택시를 타고, 돈이 없으면 걸어 간다.
#
# 프로그래밍도 위의 문장처럼 주어진 조건을 판단한 후 그 상황에 맞게 처리해야 할 경우가 있다.
# 이렇듯 프로그래밍에서 조건을 판단하여 해당 조건에 맞는 상황을 수행하는데 쓰이는 것이 if 문 이다.
# ```
# money = 1
# if money:
#     print("택시를 타자.")
# else:
#     print("걸어가자.")
# ```
# output `"택시를 타자."`
#
# money에 입력된 1은 참이다.(기억이 안난다면 Boolean 내용 참고!)
#
# 따라서 if문 다음의 문장이 수행되어 `"택시를 타자."`가 출력된다.

# %% [markdown]
# ### 1.  들여쓰기
#
# if 문을 만들 때는
#
# `if 조건문:` 바로 아래 문장부터 if 문에 속하는 모든 문장에 들여쓰기(indentation)를 해야 한다.
#
# 아래의 경우와 같이 조건문이 참일 경우,
#
# '수행할 문장1'을 들여쓰기 했고
#
# '수행할 문장2'와 '수행할 문장3'도 들여쓰기를 했다.
# ```
# if 조건문:
#     수행할 문장1
#     수행할 문장2
#     수행할 문장3
# ```
#
# 아래와 같이 작성하면 오류가 발생한다!
#
# ```
# if 조건문:
#     수행할 문장1
# 수행할 문장2
#     수행할 문장3
#
# if money:
#     print("AI")
#  print("Robotics")
# ```
# output `SyntaxError`
#
# 즉, 들여쓰기는 언제나 같은 깊이로 해야한다.
# ```
# if money:
#     print("AI")
#   print("Robotics")
#         print("KR")
# ```
# output `IndentationError`
#
#
#
# >들여쓰기는 공백(spacebar)으로 하는 것이 좋을까? 아니면 탭(tap)으로 하는 것이 좋을까?
#
# 논란이 많은 이야기이지만,
#
# 탭으로 하자는 쪽과 공백으로 하자는 쪽 모두가 동의하는 내용은 단 하나,
#
#  > 2가지를 혼용해서 쓰지는 말자는 것이다.
#
# 공백으로 할 거면 항상 공백으로 통일하고, 탭으로 할 거면 항상 탭으로 통일해서 사용하자.
# 탭이나 공백은 프로그램 소스에서 눈으로 보이는 것이 아니기 때문에 혼용해서 쓰면 에러의 원인이 되기도 한다.
# (요즘 파이썬 커뮤니티에서는 들여쓰기를 할때 공백(spacebar) 4개를 사용하는 것을 권장)

# %% [markdown]
# ### 2. 조건문 다음에 콜론(:)을 잊지 말자
#
# `if 조건문` 뒤에는 반드시 콜론(:)이 붙는다!
#
# 앞으로 배우게 될 while, for, def, class 문에도 역시 문장의 끝에 콜론(:)이 항상 들어간다.
# 초보자들은 이 콜론(:)을 빠뜨리는 경우가 많으니 특히 주의하자.
#
# ![대체 텍스트](https://media1.tenor.com/images/39798ccf38a1799e99ae5234bf59ec00/tenor.gif?itemid=8025378)
#
# 파이썬이 보기 쉽고 소스코드가 간결한 이유는 `:`을 사용하여 들여쓰기(indentation)를 하도록 만들었기 때문이다.
#
# (다른 언어에서는 if문을 `{ }`기호로 감싸지만 파이썬에서는 들여쓰기로 해결한다.)

# %%
# if문에서 주의할 것 단 2가지!
# 들여쓰기와 :을 주의하면서 한번 연습해볼까요? 가장 간단한 if문을 작성해봅시다.(들여쓰기와 :이 들어있는!)

# %% [markdown]
# ## 조건문이란?
#
# 참과 거짓을 판단하는 문장을 말한다. 자료형의 참과 거짓에 대해 다시 살펴보면 아래와 같다.
#
# 자료형|참|거짓
# ---|---|---
# 숫자|0이 아닌 숫자|0
# 문자열|"abc"|""
# 리스트|[5, 6]|[]
# 튜플|(1, 2, 3)|()
# 딕셔너리|{1: 'a'}|{}
#
#
# 앞에서 살펴본 taxi 예제에서 조건문은 money이다.
# ```
# money = 1
# if money:
# ```
# money는 1이기 때문에 참이 되어 if문 다음의 문장을 수행한다.

# %% [markdown]
# ### 비교연산자
#
# 조건의 참, 거짓을 판단할 때 자료형보다는 비교연산자를 쓰는 경우가 훨씬 많다.
#
# 비교연산자|설명
# ---|---
# a < b|a가 b보다 작다
# a > b|a가 b보다 크다
# a == b|a와 b가 같다
# a != b|a와 b가 같지 않다
# a >= b|a가 b보다 크거나 같다
# a <= b|a가 b보다 작거나 같다
#
#
# 사용 예제를 보자
# ```
# a = 3
# b = 4
# a > b
# ```
# output `False`
# ```
# c = 14
# d = 10
# c > d
# ```
# output `True`
# ```
# a == c
# ```
# output `False`
# ```
# b != d
# ```
# output `True`
#
#
#
# 앞의 택시 예제를 다음처럼 바꿔보자
#
# > 만약 3000원 이상의 돈을 가지고 있으면 택시를 타고 그렇지 않으면 걸어 가라
# ```
#         money = 2000
#         if money >= 3000:
#         	print("택시를 타자")
#         else:
#         	print("걸어 가자")
# ```
# output `"걸어 가자"`

# %%
#비교 연산자를 활용해봅시다.

# %% [markdown]
# ### and, or , not
#
# 조건을 판단하기 위해 사용하는 다른 연산자로는 and, or, not이 있다.
#
# 연산자|설명
# ---|---
# x or y|x와 y 둘 중에 하나만 참이면 참
# x and y|x와 y 모두 참이어야 참
# not x|x가 거짓이면 참
#
#
# > 돈이 3000원 이상 있거나 카드가 있다면 택시를 타고 그렇지 않으면 걸어 가라
#
# ```
# money = 2000
# card = 1
# if money >= 3000 or card:
#     print("택시를 타고 가자")
# else:
#     print("걸어 가자")
# ```
# output `"택시를 타고 가자"`
#
#
# money는 2000이지만 card가 1이기 때문에
#
# [ money >= 3000 ]-> 거짓
#
# [ card ]-> 참
#
# money >= 3000 or card라는 조건은
#
# [ 거짓 ] or [ 참 ]이되어
#
# 결론은 참이 된다.
#
# 따라서 if 문 다음의 `택시를 타고 가자`라는 문장이 수행된다.

# %%
# and, or, not을 활용해봅시다.

# %% [markdown]
# ###  x `in` s, x `not` s
#
# 파이썬은 다른 프로그래밍 언어에서 볼 수 없는 재미있는 조건문들이 있다.
#
# in|not in
# ---|---
# x in 리스트|x not in 리스트
# x in 튜플|x not in 튜플
# x in 문자열|x not in 문자열
#
# in 이라는 영어 단어의 뜻이 "~안에"라는 것을 생각해보면 이해하기 쉽다.
# ```
# 1 in [1, 2, 3]
# ```
# output `True`
# ```
# 1 not in [1, 2, 3]
# ```
# output `False`
#
# 첫 번째 예는 '[1, 2, 3]이라는 리스트 안에 1이 있는가?'라는 조건문이다.
#
# 1은 [1, 2, 3]안에 있으므로 참이 되어 True를 return한다.
#
# 두 번째 예는 '[1, 2, 3] 안에 있으므로 거짓이 되어 False를 return한다.
#
#
#
# 다음은 튜플과 문자열에 적용한 예이다.
# ```
# 'a' in ('a', 'b', 'c')
# ```
# output `True`
# ```
# 'i' not in 'python'
# ```
# output `True`
#
#
#
# 다시 택시 예제에 in을 적용해보자
#
# ```
# pocket = ['paper', 'cellphone', 'money']
# if 'money'in pocket:
#     print("택시를 타자")
# else:
#     print("걸어 가자")
# ```
# output `"택시를 타자"`
#
#
#
# ['paper', 'cellphone', 'money']라는 리스트 안에 'money'가 있으므로
#
# 'money' in pocket은 참 -> if block이 실행

# %% [markdown]
# #### 조건문에서 아무 일도 하지 않게 설정하고 싶다면?
#
# 가끔 조건문의 참, 거짓에 따라 실행할 행동을 정의할 때, 아무런 일도 하지 않도록 설정하고 싶을 때가 있다.
#
# > 주머니에 돈이 있으면 가만히 있고 주머니에 돈이 없으면 카드를 꺼내라
#
# 이럴 때 pass를 사용한다.
# ```
# pocket = ['paper', 'money', 'cellphone']
# if 'money' in pocket:
#     pass
# else:
#     print("카드를 꺼내라")
# ```
#
# pocket이라는 리스트 안에 money 라는 문자열이 있음 ->
#
# if block인 pass가 수행->
#
# 아무런 결과값도 보여 주지 않음(pass)

# %%
# in을 사용해 봅시다.

# %%
# pass도 활용해 봅시다.

# %% [markdown]
# ## 다양한 조건을 판단하는 elif
#
# if와 else만으로는 다양한 조건을 판단하기 어렵다.
# 아래의 예를 보더라도 if와 else만으로는 조건을 판단하는데 어려움을 겪게 된다.
#
# > 주머니에 돈이 있으면 택시를 타고, 주머니에 돈은 없지만 카드가 있으면 택시를 타고, 돈도 없고 카드도 없으면 걸어 가라
#
# 위의 문장을 보면 조건을 판단하는 부분이 두 군데가 있다.
# 1. 먼저 주머니에 돈이 있는지를 판단해야 하고
# 2. 주머니에 돈이 없으면 다시 카드가 있는지 판단해야 한다.
#
#
#
# if 와 else 만으로 위의 문장을 표현해보면 아래와 같다.
# ```
# pocket = ['paper', 'cellphone']
# card = 1
# if 'money' in pocket:
#     print("택시를 타고 가라")
# else:
#     if card:
#         print("택시를 타고 가라")
#     else:
#         if card:
#             print("택시를 타고 가라")
#         else:
#             print("걸어 가라")
# ```
# output `택시를 타고 가라`
#
#
# 언뜻 보기에도 이해하기 어렵고 산만한 느낌이 든다.
# 이런 복잡함을 해결사는 다중 조건 판단을 가능하게 하는 elif이다.
#  ![yeah](https://media1.tenor.com/images/d01977089185ddbc20cd3005144dea82/tenor.gif?itemid=8025384)
#
# ```
# pocket = ['paper', 'cellphone']
# card = 1
# if 'money' in pocket:
#     print("택시를 타고 가라")
# elif card:                               #여기!!!
#     print("택시를 타고 가라")
# else:
#     print("걸어 가라")
# ```
# output `택시를 타고 가라`
#
#
#
# elif는 이전 조건문의 거짓일 때 수행된다. if, elif, else를 모두 사용할 때 기본 구조는 아래와 같다.
# ```
# if 조건문:
#     수행할 문장 1-1
#     수행할 문장 1-2
#     ...
# elif 조건문2:
#     수행할 문장 2-1
#     수행할 문장 2-2
#     ...
# elif 조건문N:
#     수행할 문장 N-1
#     수행할 문장 N-2
#     ...
# else:
#     수행할 문장A
#     수행할 문장B
# ```
# elif는 개수에 제한 없이 사용할 수 있다! 무한 조건 생성 능력 장착!!

# %%
#elif를 사용하여 더 다양한 조건들을 판단하여 봅시다.

# %% [markdown]
# ### if 문을 한 줄로 작성하기
#
# 앞의 pass를 사용한 예를 보면 if문 다음에 수행할 문장이 한 줄이고, else문 다음에 수행할 문장도 한줄 밖에 되지 않는다.
# ```
# if 'money' in pocket:
#     pass
# else:
#     print("카드를 꺼내라")
# ```
# 이렇게 수행할 문장이 한 줄일 때 조금 더 간략하게 코드를 작성하는 방법이 있다.
# ```
# pocket = ['paper', 'money', 'cellphone']
# if 'money' in pocket: pass
# else: print("카드를 꺼내라")
# ```
# if 문 다음에 수행할 문장을 콜론(:) 뒤에 바로 적어 주었다. else 문 역시 마찬가지이다.
#
# 때때로 이렇게 작성하는 것이 보기 편할 수 있다.

# %%
#조건문 다음에 바로 수행할 문장을 적어주는 if문을 작성해봅시다.

# %% [markdown]
# # while문
#
# ## While문의 기본 구조
#
# 반복해서 문장을 수행해야 할 경우 while문을 사용한다. 그래서 while문을 반복문이라고도 부른다.
# ```
#     while 조건문:
#     	수행할 문장1
#     	수행할 문장2
#     	수행할 문장3
#     	...
# ```
# while문은 조건문이 참인 동안에 while문 아래에 속하는 문장드링 반복해서 수행된다.
#
#
#
#
# '열 번 찍어 안 넘어가는 나무 없다'라는 속담을 파이썬 프로그램으로 만들어보자.
#
# ```
# treeHit = 0
# while treeHit < 10:
#     treeHit = treeHit + 1
#     print("나무를 %d번 찍었습니다."% treeHit)
#     if treeHit == 10:
#             print("나무가 넘어갔습니다.")
# ```
#
# output
# ```
# 나무를 1번 찍었습니다.
# 나무를 2번 찍었습니다.
# 나무를 3번 찍었습니다.
# 나무를 4번 찍었습니다.
# 나무를 5번 찍었습니다.
# 나무를 6번 찍었습니다.
# 나무를 7번 찍었습니다.
# 나무를 8번 찍었습니다.
# 나무를 9번 찍었습니다.
# 나무를 10번 찍었습니다.
# 나무가 넘어갔습니다.
# ```
# while 문의 조건문은 `treeHit < 10`이다. (=  treeHit가 10보다 작은 동안에 while문 안의 문장들을 계속 수행)
#
#
# while문 안의 문장을 보면 ,
#
# 1. 제일 먼저 treeHit = treeHit + 1로 treeHit 값이 계속 1씩 증가한다.
#
# 2. 나무를 treeHit번 만큼 찍었음을 알리는 문장을 출력하고 treeHit가 10이 되면 '나무 넘어갑니다.'라는 문장을 출력한다.
#
# 3. 그러고 나면 treeHit이 10이 되는 순간,  treeHit < 10이라는 조건문이 거짓이 되므로 while문을 빠져나가게 된다.
#
#
#
# 다음은 while문이 반복되는 과정을 순서대로 정리한 표이다.
#
# 이렇게 긴 과정을 소스 코드 단 5줄로 만들 수 있다니 놀랍지 않은가?
#
# treeHit|조건문|조건 판단|while|수행하는 문장
# ---|---|---|---|---
# 0|0<10|True|반복|나무를 1번 찍었습니다.
# 1|1<10|True|반복|나무를 2번 찍었습니다.
# 2|2<10|True|반복|나무를 3번 찍었습니다.
# 3|3<10|True|반복|나무를 4번 찍었습니다.
# 4|4<10|True|반복|나무를 5번 찍었습니다.
# 5|5<10|True|반복|나무를 6번 찍었습니다.
# 6|6<10|True|반복|나무를 7번 찍었습니다.
# 7|7<10|True|반복|나무를 8번 찍었습니다.
# 8|8<10|True|반복|나무를 9번 찍었습니다.
# 9|9<10|True|반복|나무를 10번 찍었습니다./n 나무가 넘어갔습니다.
# 10|10<10|False|종료

# %%
# whlie문을 한번 연습해봅시다.
#아직은 기본구조를 익히는게 중요하므로 위의 나무 속담예제를 그대로 작성해봅시다.
#10번 찍어서 나무를 쓰러뜨려봅시다!

# %% [markdown]
# ## While문 직접 만들기
#
# 다음은 여러가지 선택지 중 하나를 선택해서 입력받는 예제이다.
#
# 먼저 다음과 같이 여러 줄짜리 문자열을 만들어 보자.
# ```
# prompt = """
# 1. Add
# 2. Del
# 3. List
# 4. Quit
#
# Enter number: """
# ```
#
# 이어서 number 라는 변수에 0을 먼저 대입한다.
#
# number라는 변수를 먼저 설정해놓지 않으면 다음에 나올 while문의 조건문인 number!=4에서 변수가 존재하지 않는다는 에러가 발생한다.
#
# ```
# number = 0
#
# while number != 4:
#     print(prompt)
#     number = int(input())
# ```
# output
# ```
# 1. Add
# 2. Del
# 3. List
# 4. Quit
#
# Enter number:
# ```
#
#
# while 문을 보면 number가 4가 아닌동안 prompt를 출력하고 사용자로부터 번호를 입력받는다. 다음의 결과 화면처럼 사용자가 4라는 값을 입력하지 않으면 계속해서 prompt를 출력한다.
#
#
# output
# ```
# Enter number:
# 1
#
# 1. Add
# 2. Del
# 3. List
# 4. Quit
# # 4를 입력하지 않으면 계속해서 prompt 출력
# ```
#
#
# 여기서 `number = int(input())`는 사용자의 숫자 입력을 받아  integer 정수로 바꾸어 주는 코드이다.
#
# `int()`는 data를 정수형 자료로 바꾸어 주는 내장함수라고 알고 넘어가자.
#
#
# `4`를 입력하면 조건문이 거짓이 되어 while 문을 빠져나가게 된다.
# ```
# Enter number:
# 4
# # 끝남
# ```

# %%
#While문을 직접 만드는 실습을 그대로 따라해보고 출력해봅시다.

# %% [markdown]
# ## While문 강제로 빠져나가기
#
# while문은 조건문이 참인 동안 계속해서 while문 안의 내용을 반복적으로 수행한다. 하지만 강제로 while 문을 빠져나가고 싶을 떄가 있다.
#
#
# 예를 들어 커피 자판기를 생각해보자. 자판기 안에 커피가 충분히 있을 때에는 동전을 넣으면 커피가 나온다. 그런데 자판기가 제대로 작동하려면 커피가 얼마나 남았는지 항상 검사해야 한다. 만약 커피가 떨어졌다면 판매를 중단하고 '판매 중지'라는 문구를 사용자에게 보여주어야 한다.
#
# 이렇게 판매를 강제로 멈추게 하는 것이 바로 break 문이다.
#
# 커피 자판기 이야를 파이썬 코드로 풀어보자.
#
# ```
# coffee = 10
# money = 300
# while money:
#     print("돈을 받았으니 커피를 줍니다.")
#     coffee = coffee -1
#     print("남은 커피의 양은 %d개 입니다." % coffee)
#     if not coffee:
#         print("커피가 다 떨어졌습니다. 판매를 중지합니다.")
#         break #여기!!!
# ```
# 1. `money`가 `300`으로 고정되어 있으므로 `while money:`에서 조건문인 money는 0이 아니기 때문에 항상 참이다. 따라서 무한히 반복되는 무한 루프를 돌게 된다.
#
# 2. while 문의 내용을 한 번 수행할 때마다 `coffee = coffee -1`에 의해서 `coffee`의 개수가 1개씩 줄어든다. 만약 coffee가 `0`이 되면 `if not coffee:`라는 문장에서 `not coffee` 가 참이 되므로 if문 다음의 문장인 `"커피가 다 떨어졌습니다. 판매를 중지합니다."`가 수행된다.
#
# 3. `break` 문이 호출되어 while 문을 빠져나가게 된다.

# %% [markdown]
# ###  break 문 이용해 자판기 작동 과정 만들기
#
# 하지만 실제 자판기는 위의 예처럼 작동하지는 않을 것이다. 다음은 자판기의 실제 작동 과정과 비슷하게 만들어 본 예이다. 이해가 안되더라도 걱정하지 말자.
#
# ```
# coffee = 10
#
# while True:
#     money = int(input("돈을 넣어 주세요: "))
#
#     if money == 300:
#         print("커피를 줍니다.")
#         coffee = coffee - 1
#
#     elif money > 300:
#         print("거스름돈 %d를 주고 커피를 줍니다." %(money-300))
#         coffee = coffee -1
#
#     else:
#         print("돈을 다시 돌려주고 커피를 주지 않습니다.")
#         print("남은 커피의 양은 %d개 입니다.")
#
#     if not coffee:
#         print("커피가 다 떨어졌습니다. 판매를 중지합니다.")
#         break
# ```
# 위의 소스 코드를 입력하면서 무슨 내용인지 이해할 수 있다면 지금껏 배운 if 문이나 while문을 이해했다고 보면 된다.

# %%
#break와 친해지기!!
#이해가 조금 어렵더라도 실제 자판기의 코드를 작성해보자. 때론 손을 움직일 때 머리가 더 잘 돌아간다.
#입력란에 여러 숫자를 입력해 보면서 결과를 확인하자.

# %% [markdown]
# ## 조건에 맞지 않는 경우 맨 처음으로 돌아가기
#
# while 문 안의 문장을 수행할 때 입력된 조건을 검사해서 조건에 맞지 않으면 while문을 빠져나간다.
#
# 그런데 프로그래밍을 하다 보면, while문을 빠져나가지 않고 while문의 맨 처음(조건문)으로 다시 돌아가게 만들고싶은 경우가 생기게 된다.
#
# 이때 사용하는 것이 바로 `continue` 문이다!
#
# 만약 1부터 10까지의 숫자 중에서 홀수만 출력하는 것을 while문을 이용해서 작성한다고 생각해보자.
#
# 어떤 방법이 좋을까?
#
# ![대체 텍스트](https://i.pinimg.com/originals/d8/a5/a2/d8a5a2b7b1abfc025f32b7fc7dadde26.jpg)
# ```
# a = 0
# while a < 10:
#     a = a+1
#     if a%2 == 0:continue
#     print(a)
# ```
# output
# ```
#     1
#     3
#     5
#     7
#     9
# ```
#
# 위의 예는 1부터 10까지의 숫자 중 홀수만을 출력하는 예이다.
#
# 1. a가 10보다 작은 동안 a는 1만큼씩 계속 증가한다.
#
# 2. `if a%2 == 0`(a를 2로 나누었을 때 나머지가 0인 경우)이 참이 되는 경우는 a가 짝수일 때이다. 즉, a가 짝수이면 `continue` 문장을 수행한다.
#
# 3. continue 문은 while문의 맨 처음(조건문: `a<10`)으로 돌아가게 하는 명령어이다. 따라서 위의 예에서 a가 짝수이면 print(a)는 수행되지 않을 것이다.

# %%
#위의 예를 그대로 따라해보면서 continue와 친해져보자.

# %% [markdown]
# ## 무한루프
#
# 무한 루프란 무한히 반복한다는 의미이다.  우리가 사용하는 일반적인 프로그램 중에서 무한 루프의 개념을 사용하지 않는 프로그램은 거의 없다. 그만큼 자주 사용된다.
#
# 파이썬에서 무한 루프는 while문으로 구현할 수 있다. 아래는 무한 루프의 기본적인 형태이다.  while문의 조건문이 `True`이므로 항상 참이 된다. 따라서 while문 안에 있는 문장들은 무한하게 수행될 것이다.
# ```
# while True:
#     수행할 문장1
#     수행할 문장2
#     ...
# ```
#
#
# 다음은 무한 루프 예이다.
# ```
# while True:
#     print("Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.")
# ```
# output
# ```
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# ...
# ```
# 위의 문장은 영원히 출력된다. 하지만 이 예처럼 아무 의미 없이 무한 루프를 돌리는 경우는 거의 없을 것이다. [Ctrl + C]를 눌러 빠져나가도록 하자.

# %%
#무한루프속에 한번 빠져보시죠!ㅎㅎ
#우리는 콜렙을 사용하기 때문에 코드창의 왼쪽상단 정지버튼을 누르셔야 멈출 수 있습니다.

# %% [markdown]
# # for 문
#
# 파이썬의 직관적인 특징을 가장 잘 대변해 주는 것이 for문이다.
#
# while 문과 비슷한 반복문인 for문은 매우 유용하고 문장 구조가 한눈에 쏙 들어온다는 장점이 있다.
#
# for문을 잘 사용하면 프로그래밍이 때때로 즐거워질 것이다.
#
# ## for문의 기본 구조
#
# for 문의 기본적인 구조는 아래와 같다.
#
# ```
# for 변수 in 리스트(또는 튜플, 문자열):
#     수행할 문장1
#     수행할 문장2
#     ...
# ```
#
# 리스트나 튜플, 문자열의 첫 번째 요소부터 마지막 요소까지 차례로 변수에 대입되어 `'수행할 문장1'`, `'수행할 문장2'`등이 수행된다.

# %% [markdown]
# ### 예제 이용해 for 문 이해하기
#
# for 문은 예제를 통해서 살펴보는 것이 가장 알기 쉬우므로 한번 살펴보자!
#
#
# 1. 전형적인 for 문
#
# ```
# test_list = ['one', 'two', 'three']
# for i in test_list:
#     print(i)
# ```
#
# output
# ```
# one
# two
# three
# ```
#
# `['one', 'two', 'three']`라는 리스트의 첫 번째 요소인 `'one'`이 먼저 `i` 변수에 대입된 후 `print(i)`라는 문장을 수행한다. 다음에 `'two'`라는 두 번째 요소가 `i`변수에 대입된 후 `print(i)` 문장을 수행하고 리스트의 마지막 요소까지 이것을 반복한다.

# %%
#전형적인 for문이라는 건 지루한게 아니라 아주 기초적이고 중요한 형식이니 한번 연습해봐요~

# %% [markdown]
# 2. 다양한 for문의 사용
# ```
# a = [(1,2), (3,4), (5,6)]
# for (first, last) in a:
#     print(first + last)
# ```
# output
# ```
# 3
# 7
# 11
# ```
# 위 예는 a 리스트의 요솟값이 튜플이기 때문에 각각의 요소가 자동으로 `(first, last)` 변수에 대입된다.
#
# - 이 예는 튜플에서 사용한 변수값 대입 방법과 매우 비슷하다.
#
# `(first, last) = (1, 2)`

# %%
# 튜플이 아름답게 알아서 들어가는 것도 실습해봅시다!

# %% [markdown]
# 3. for 문의 응용
#
# 다음을 가정해 보자.
#
# > 총 5명의 학생이 시험을 보았는데 시험 점수가 60점이 넘으면 합격이고 그렇지 않으면 불합격이다. 합격인지 불합격인지 결과를 보여 주시오.
#
#
# 우선 학생 5명의 시험 점수를 리스트로 표현해 보았다.
# ```
# marks = [90, 25, 67, 45, 80]
# ```
# 1번 학생은 90점이고 5번 학생은 80점이다.
#
# 이런 점수를 차례로 검사해서 합격했는지 불합격했는지 통보해 주는 프로그램을 만들어 보자.
# ```
#     marks = [90, 25, 67, 45, 80]
#
#     number = 0
#     for mark in marks:
#         number = number +1
#         if mark >= 60:
#             print("%d번 학생은 합격입니다." % number)
#         else:
#             print("%d번 학생은 불합격입니다." % number)
# ```
#
# * 각각의 학생에게 번호를 붙여 주기 위해 number 변수를 사용하였다.
# * 점수 리스트 marks에서 차례로 점수를 꺼내어 mark라는 변수에 대입하고 for문 안의 문장들을 수행한다.
# * for문이 한 번씩 수행될 때마다 number는 1씩 증가한다.
#
# 이 프로그램을 실행하면 `mark`가 60 이상일 때 합격 메시지를 출력하고 60을 넘지 않을 때 불합격 메시지를 출력한다.
#
# output
# ```
# 1번 학생은 합격입니다.
# 2번 학생은 불합격입니다.
# 3번 학생은 합격입니다.
# 4번 학생은 불합격입니다.
# 5번 학생은 합격입니다.
# ```

# %%
#학생들의 합격/불합격을 판단해주는 프로그램을 따라 만들어 봅시다.

# %% [markdown]
# ## for문과 continue
#
# while문에서 살펴본 continue문을 for문에서도 사용할 수 있다.
#
# for문 안의 문장을 수행하는 도중에 continue문을 만나면 for문의 처음으로 돌아가게 된다.
#
# 앞에서 for문 응용 예제를 그대로 사용해서 60점 이상인 사람에게는 축하 메시지를 보내고 나머지 사람에게는 아무 메시지도 전하지 않는 프로그램을 에디터를 사용해 작성해 보자.(너무 매정한 예제이지만 continue를 위한 예제일 뿐이라고 생각하자ㅠㅠ)
#
#
# ![대체 텍스트](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRJALTVxz6ch7vTRoSCSog0Z5A_sDtdLEq2gHpDYxtrVN_mN1M_)
#
#
# ```
# marks = [90, 25, 67, 45, 80]
#
# number = 0
# for mark in marks:
#     number = number +1
#     if mark < 60:
#         continue
#     print("%d번 학생 축하합니다. 합격입니다. " % number)
#
# ```
#
#
# 점수가 60점 이하인 학생일 경우에는 mark < 60이 참이 되어 continue문이 수행된다. 따라서 축하 메시지를 출력하는 부분인 print문을 수행하지 않고 for문의 처음으로 돌아가게 된다.
#
# output
# ```
# 1번 학생 축하합니다. 합격입니다.
# 3번 학생 축하합니다. 합격입니다.
# 5번 학생 축하합니다. 합격입니다.
# ```

# %%
#메세지 예제도 똑같이 작성해보자.

# %% [markdown]
# ## for와 함께 자주 사용하는 range 함수
#
# for문은 숫자 리스트를 자동으로 만들어 주는 range 함수와 함께 사용하는 경우가 많다.
#
# 다음은 range 함수의 간단한 사용법이다.
# ```
# a = range(10)
# a
# ```
# output `range(0, 10)`
#
#
# `range(10)`은 0부터 10 미만의 숫자를 포함하는 range 객체를 만들어 준다.
#
# 시작 숫자와 끝 숫자를 지정하려면 `range(시작 숫자, 끝 숫자)` 형태를 사용하는데, 이때 끝 숫자는 포함되지 않는다.(앞서 배운 슬라이싱에서와 비슷하다.)
# ```
# a = range(1, 11)
# a
# ```
# output `range(1, 11)`
#
# ### range 함수의 예시 살펴보기
#
# for와 range 함수를 사용하면 1부터 10까지 더하는 것을 다음과 같이 쉽게 구현할 수 있다.
# ```
# sum = 0
# for i in range(1, 11):
#     sum = sum + i
#
# print(sum)
# ```
# output `55`
#
# `range(1, 11)`은 숫자 1부터 10까지(1 이상 11 미만)의 숫자를 데이터로 갖는 객체이다.
#
# 따라서 위 예에서 `i` 변수에 리스트의 숫자가 1부터 10까지 하나씩 차례로 대입되면서 `add = add + i` 문장을 반복적으로 수행하고 add는 최종적으로 `55`가 된다.

# %%
#range함수를 사용하여 1부터 100까지 더해봅시다.

# %% [markdown]
# 우리가 앞에서 살본 `"60점 이상이면 합격"`이라는 문장을 출력하는 예제도 range 함수를 사용해서 바꿔보자.
#
# ```
# marks = [90, 25, 67, 45, 80]
# for number in range(len(marks)):
#     if marks[number] < 60: continue #점수가 60점 미만이면 맨 처음으로 돌아간다.
#     print("%d번 학생 축하합니다. 합격입니다." % (number+1))
# ```
#
# * len 함수는 리스트 안의 요소 개수를 돌려주는 함수
#
# `len(marks)` 는 `5`
#
# `range(len(marks))`는 `range(5)`가 될 것이다.
#
# `number` 변수에는 차례로 0부터 4까지의 숫자가 대입되고,
# `marks[number]`는 차례대로 `90`, `25`, `67`, `45`, `80`값을 갖게 된다.

# %%
#위의 예제를 그대로 써보면서 range와 친해져 봅시다.

# %% [markdown]
# ### for와 range를 이용한 구구단
#
# `for`와 `range` 함수를 사용하면 소스 코드 단 4줄만으로 구구단을 출력할 수 있다. 들여쓰기에 주의하며 입력해 보자.
# ```
# for i in range(2,10):      # ①번 for문
#     for j in range(1, 10):   # ②번 for문
#         print(i*j, end=" ")
#     print('')
# ```
#
# output
# ```
# 2 4 6 8 10 12 14 16 18
# 3 6 9 12 15 18 21 24 27
# 4 8 12 16 20 24 28 32 36
# 5 10 15 20 25 30 35 40 45
# 6 12 18 24 30 36 42 48 54
# 7 14 21 28 35 42 49 56 63
# 8 16 24 32 40 48 56 64 72
# 9 18 27 36 45 54 63 72 81
# ```
# 위 예를 보면 for문을 두 번 사용했다.
#
#
# ①번 for문에서 2부터 9까지의 숫자(`range(2, 10)`)가 차례로 i에 대입되고, i가 처음 2일 때 ②번 for문을 만나게 된다.
#
# ②번 for문에서 1부터 9까지의 숫자(`range(1, 10)`)가 j에 대입되고 그 다음 문장 `print(i*j)`를 수행한다.
#
#
# 따라서 i가 2일 때 `2*1`, `2*2`, `2*3`, … `2*9`까지 차례로 수행되며 그 값을 출력하게 된다. 그 다음으로 i가 3일 때 역시 2일 때와 마찬가지로 수행될 것이고 i가 9일 때까지 계속 반복된다.
#
#
#
# #### print함수 입력인수에 `end`를 넣어 준 이유는 무엇일까?
#
# 앞의 예제에서 `print(i*j, end=" ")`와 같이 매개변수 end를 넣어 준 이유는 해당 결괏값을 출력할 때 다음줄로 넘기지 않고 그 줄에 계속해서 출력하기 위해서이다. 그 다음에 이어지는 `print(' ')`는 2단, 3단 등을 구분하기 위해 두 번째 for문이 끝나면 결괏값을 다음 줄부터 출력하게 해주는 문장이다.

# %%
#구구단을 찍어보자
#능력이 된다면 19단도...?!

# %% [markdown]
# ## 리스트 안에 for문 포함하기
#
# 리스트 안에 for문을 포함하는 리스트 내포(List comprehension)를 사용하면 좀 더 편리하고 직관적인 프로그램을 만들 수 있다. 다음 예제를 보자.
#
# ```
# a = [1,2,3,4]
# result = []
# for num in a:
#     result.append(num*3)
#
# print(result)
# ```
# output `[3, 6, 9, 12]`
#
#
# 위 예제는 a 리스트의 각 항목에 3을 곱한 결과를 result 리스트에 담는 예제이다.
#
# 이것을 리스트 내포를 사용하면 다음과 같이 간단히 해결할 수 있다!
#
# ![yeah](https://media1.tenor.com/images/d01977089185ddbc20cd3005144dea82/tenor.gif?itemid=8025384)
#
# ```
# a = [1,2,3,4]
# result = [num * 3 for num in a]
# print(result)
# ```
# output `[3, 6, 9, 12]`
#
#
# 만약 `[1,2,3,4]` 중에서 짝수에만 3을 곱하여 담고 싶다면 다음과 같이 리스트 내포 안에 "if 조건"을 사용할 수 있다.
#
# ```
# a = [1,2,3,4]
# result = [num * 3 for num in a if num % 2 == 0] #뒤에서부터 읽어봐요~
# print(result)
# ```
# output `[6, 12]`

# %%
#리스트 안에 for문을 넣어봅시다~

# %%
#리스트 안에 for문 받고 if 까지!!

# %% [markdown]
# 리스트 내포의 일반 문법은 다음과 같다. "if 조건" 부분은 앞의 예제에서 볼 수 있듯이 생략할 수 있다.
#
# `[표현식 for 항목 in 반복가능객체 if 조건문]`
#
#
# 조금 복잡하지만 for문을 2개 이상 사용하는 것도 가능하다.
#
# for문을 여러 개 사용할 때의 문법은 다음과 같다.
#
# ```
# [표현식 for 항목1 in 반복가능객체1 if 조건문1
#         for 항목2 in 반복가능객체2 if 조건문2
#     ...
#     for 항목n in 반복가능객체n if 조건문n]
#
# ```
# 만약 구구단의 모든 결과를 리스트에 담고 싶다면 리스트 내포를 사용하여 다음과 같이 간단하게 구현할 수도 있다.
#
# ```
# result = [x*y for x in range(2,10)
#               for y in range(1,10)]
# print(result)
# ```
#
# output
# ```
# [2, 4, 6, 8, 10, 12, 14, 16, 18, 3, 6, 9, 12, 15, 18, 21, 24, 27, 4, 8, 12, 16,
# 20, 24, 28, 32, 36, 5, 10, 15, 20, 25, 30, 35, 40, 45, 6, 12, 18, 24, 30, 36, 42
# , 48, 54, 7, 14, 21, 28, 35, 42, 49, 56, 63, 8, 16, 24, 32, 40, 48, 56, 64, 72,
# 9, 18, 27, 36, 45, 54, 63, 72, 81]
# ```

# %%
# list 안에 for문 넣어서 연습하기

# %% [markdown]
# 지금껏 우리는 프로그램 흐름을 제어하는 if문, while문, for문에 대해 알아보았다.
#
# ![대체 텍스트](https://media1.tenor.com/images/b53b732d61a1ab47ac19ada4d69a5713/tenor.gif?itemid=8025409)
#
# 아마도 여러분은 `while`문과 `for`문을 보면서 2가지가 아주 비슷하다는 느낌을 받았을 것이다. 실제로 for문을 사용한 부분을 while문으로 바꿀 수 있는 경우도 많고, while문을 for문으로 바꾸어서 사용할 수 있는 경우도 많다.
